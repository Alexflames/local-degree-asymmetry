# %%
import main
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# # Test

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=1, n=10000, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# c:\Users\alexp\Documents\Studies\network-analysis\average_distribution_annd.py:84: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Doing configuration experiment
# Experiment №0. Elapsed time:  0.13
# Analyzing values from files: ['output/out_cm_10000_2.5_dist_as_brank.txt', 'output/out_cm_10000_2.5_dist_sig_brank.txt', 'output/out_cm_10000_2.5_dist_cv_brank.txt']
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=100000, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Experiment №8. Elapsed time:  9.95
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Experiment №9. Elapsed time:  12.12
# Analyzing values from files: ['output/out_cm_100000_2.5_dist_as_brank.txt', 'output/out_cm_100000_2.5_dist_sig_brank.txt', 'output/out_cm_100000_2.5_dist_cv_brank.txt']
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 5, 
                  degree_exponent=3.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 6, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 6, 
                  degree_exponent=3.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_BA, number_of_experiments=10, n=10 ** 5,
                  m=3,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing barabasi-albert experiment
# Experiment №8. Elapsed time:  2.67
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Experiment №9. Elapsed time:  2.94
# Analyzing values from files: ['output/out_ba_1000_3_dist_as_beta.txt', 'output/out_ba_1000_3_dist_sig_beta.txt', 'output/out_ba_1000_3_dist_cv_beta.txt', 'output/out_ba_1000_3_dist_as_brank.txt', 'output/out_ba_1000_3_dist_sig_brank.txt', 'output/out_ba_1000_3_dist_cv_brank.txt']
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_BA, number_of_experiments=10, n=10 ** 5,
                  m=5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
                  filename="musae_git_edges.txt",
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing from_file experiment
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\networkx\classes\graph.py:2010, in Graph.nbunch_iter.<locals>.bunch_iter(nlist, adj)
#    2009 try:
# -> 2010     for n in nlist:
#    2011         if n in adj:
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
#       2                   filename="musae_git_edges.txt",
#       3                   save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:1070, in run_external(experiment_type, number_of_experiments, n, m, p, degree_exponent, focus_indices, focus_period, save_data, value_to_analyze, values_to_analyze, apply_log_binning, progress_bar, filename, real_directed)
#    1068     threading.Thread(target=run_internal).start()
#    1069 else:
# -> 1070     run_internal()
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:1076, in run_internal()
#    1074 print("Doing %s experiment" % input_type)
#    1075 if input_type == "from_file":
# -> 1076     experiment_file()
#    1077 elif input_type == "barabasi-albert":
#    1078     experiment_ba()
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:649, in experiment_file()
#     645             node_from, node_to = line_split[0], line_split[1]
#     646             graph.add_edge(node_from, node_to)
# --> 649     filenames = analyze_mult_val_graph(graph, "output/" + _filename, overwrite=True)
#     650     obtain_value_distribution(filenames)
#     651 elif real_dynamic:
#     652     # анализ динамики средней степени соседей и её дисперсии в динамических реальных сетях
#     653
#    (...)
#     656     # для каждого узла записывается средняя степень соседей на итерациях из массива dynamic_iterations
#     657     # для каждой группы узлов записываются дисперсии
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:514, in analyze_mult_val_graph(graph, filename, overwrite)
#     512 filenames = []
#     513 for value in _values_to_analyze:
# --> 514     filenames += analyze_val_graph(graph, filename, value, overwrite)
#     515 return filenames
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:535, in analyze_val_graph(graph, filename, value_to_analyze, overwrite)
#     533     calculate_rank_dictionary(graph)
#     534 value_function = get_value_function(value_to_analyze)
# --> 535 deg2sum_count, deg2values = acquire_value_distribution(graph, value_function, _apply_log_binning)
#     537 if value_to_analyze == DEG_BETA or value_to_analyze == DEG_BETA_RANK:
#     538     # Вычислить таблицу степень -> Сколько Значений больше > _граничное_значение
#     539     value_to_analyze_name = get_filename_suffix_value_to_analyze(value_to_analyze)
#
# File c:\Users\alexp\Documents\Studies\network-analysis\main.py:269, in acquire_value_distribution(graph, node_value_function, use_log_binning)
#     266 max_degree = 0
#     268 for node in graph_nodes:
# --> 269     degree = graph.degree(node)
#     270     value = node_value_function(graph, node)
#     271     deg2sum_count_cur = deg2sum_count.get(degree, (0, 0))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\networkx\classes\reportviews.py:436, in DiDegreeView.__call__(self, nbunch, weight)
#     434 except TypeError:
#     435     pass
# --> 436 return self.__class__(self._graph, nbunch, weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\networkx\classes\reportviews.py:421, in DiDegreeView.__init__(self, G, nbunch, weight)
#     419 self._succ = G._succ if hasattr(G, "_succ") else G._adj
#     420 self._pred = G._pred if hasattr(G, "_pred") else G._adj
# --> 421 self._nodes = self._succ if nbunch is None else list(G.nbunch_iter(nbunch))
#     422 self._weight = weight
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\networkx\classes\graph.py:2025, in Graph.nbunch_iter.<locals>.bunch_iter(nlist, adj)
#    2021 if "hashable" in message:
#    2022     exc = NetworkXError(
#    2023         f"Node {n} in sequence nbunch is not a valid node."
#    2024     )
# -> 2025 raise exc
#
# NetworkXError: nbunch is not a node or a sequence of nodes.
