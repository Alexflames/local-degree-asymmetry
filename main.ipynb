# %%
import main
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# # Test

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=1, n=10000, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# No handles with labels found to put in legend.
# Doing configuration experiment
# Experiment №1. Elapsed time:  0.1
# Analyzing values from files: ['output/out_cm_10000_2.5_dist_as_brank.txt', 'output/out_cm_10000_2.5_dist_sig_brank.txt', 'output/out_cm_10000_2.5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## CM 100.000, $\gamma$ = 2.5

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=100000, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Experiment №10. Elapsed time:  10.56
# Analyzing values from files: ['output/out_cm_100000_2.5_dist_as_beta.txt', 'output/out_cm_100000_2.5_dist_sig_beta.txt', 'output/out_cm_100000_2.5_dist_cv_beta.txt', 'output/out_cm_100000_2.5_dist_as_brank.txt', 'output/out_cm_100000_2.5_dist_sig_brank.txt', 'output/out_cm_100000_2.5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## CM 100.000, $\gamma$ = 3.5

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 5, 
                  degree_exponent=3.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Experiment №9. Elapsed time:  8.67
# No handles with labels found to put in legend.
# Experiment №10. Elapsed time:  9.79
# Analyzing values from files: ['output/out_cm_100000_3.5_dist_as_beta.txt', 'output/out_cm_100000_3.5_dist_sig_beta.txt', 'output/out_cm_100000_3.5_dist_cv_beta.txt', 'output/out_cm_100000_3.5_dist_as_brank.txt', 'output/out_cm_100000_3.5_dist_sig_brank.txt', 'output/out_cm_100000_3.5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## CM 1.000.000, $\gamma$ = 2.5

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 6, 
                  degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Experiment №10. Elapsed time:  116.79
# Analyzing values from files: ['output/out_cm_1000000_2.5_dist_as_beta.txt', 'output/out_cm_1000000_2.5_dist_sig_beta.txt', 'output/out_cm_1000000_2.5_dist_cv_beta.txt', 'output/out_cm_1000000_2.5_dist_as_brank.txt', 'output/out_cm_1000000_2.5_dist_sig_brank.txt', 'output/out_cm_1000000_2.5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## CM 1.000.000, $\gamma$ = 3.5

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_CM, number_of_experiments=10, n=10 ** 6, 
                  degree_exponent=3.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Experiment №9. Elapsed time:  93.11
# No handles with labels found to put in legend.
# Experiment №10. Elapsed time:  103.57
# Analyzing values from files: ['output/out_cm_1000000_3.5_dist_as_beta.txt', 'output/out_cm_1000000_3.5_dist_sig_beta.txt', 'output/out_cm_1000000_3.5_dist_cv_beta.txt', 'output/out_cm_1000000_3.5_dist_as_brank.txt', 'output/out_cm_1000000_3.5_dist_sig_brank.txt', 'output/out_cm_1000000_3.5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## BA 100.000, $m = 3$

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_BA, number_of_experiments=1, n=10 ** 5,
                  m=3,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing barabasi-albert experiment
# No handles with labels found to put in legend.
# Experiment №1. Elapsed time:  2824.84
# Analyzing values from files: ['output/out_ba_100000_3_dist_as_beta.txt', 'output/out_ba_100000_3_dist_sig_beta.txt', 'output/out_ba_100000_3_dist_cv_beta.txt', 'output/out_ba_100000_3_dist_as_brank.txt', 'output/out_ba_100000_3_dist_sig_brank.txt', 'output/out_ba_100000_3_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## BA 100.000, $m = 5$

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_BA, number_of_experiments=1, n=10 ** 5,
                  m=5,
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing barabasi-albert experiment
# No handles with labels found to put in legend.
# Experiment №1. Elapsed time:  3490.89
# Analyzing values from files: ['output/out_ba_100000_5_dist_as_beta.txt', 'output/out_ba_100000_5_dist_sig_beta.txt', 'output/out_ba_100000_5_dist_cv_beta.txt', 'output/out_ba_100000_5_dist_as_brank.txt', 'output/out_ba_100000_5_dist_sig_brank.txt', 'output/out_ba_100000_5_dist_cv_brank.txt']
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## GIT network

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
                  filename="musae_git_edges.txt",
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing from_file experiment
# c:\WithoutPermission\PortableTEX\fi_dynamics\fi_source_code\average_distribution_annd.py:84: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Facebook artists

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
                  filename="artist_edges.txt",
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing from_file experiment
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Twitter

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
                  filename="soc-twitter-follows.txt",
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing from_file experiment
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Flickr

# %%
main.run_external(experiment_type=main.EXPERIMENT_TYPE_FROM_FILE,
                  filename="soc-flickr.txt",
                  save_data=True, values_to_analyze=[main.DEG_BETA, main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing from_file experiment
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
