# %%
import main

# %%
main.run_external(experiment_type_num=4, number_of_experiments=1, n=10000, degree_exponent=2.5,
                  save_data=True, values_to_analyze=[main.DEG_BETA_RANK], apply_log_binning=False)
# Out:
# Doing configuration experiment
# Successfully generated sequence of size 10000 after 1 tries
# Elapsed time:  0.13
# Analyzing values from files: ['output/out_cm_10000_2.5_dist_as_brank.txt', 'output/out_cm_10000_2.5_dist_sig_brank.txt', 'output/out_cm_10000_2.5_dist_cv_brank.txt']
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
